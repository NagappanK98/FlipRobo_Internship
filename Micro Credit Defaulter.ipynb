# %% [markdown]
# # Micro Credit Defaulter Project

# %% [markdown]
# # In this model we are going to predict the "Defaulter" ie who will not pay the loan from the given dataset

# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv('Data file.csv')
df.drop('Unnamed: 0',axis='columns', inplace=True)
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
# checking distribution of object features

for col in df.columns:
    if df[col].dtype=="object":
        print(df[col].value_counts())
        print()
# Out:
# 47819I90840    7
# 04581I85330    7
# 67324I84453    6
# 71742I90843    6
# 42825I88688    6
#               ..
# 86795I90583    1
# 38720I90586    1
# 39730I84458    1
# 71493I82731    1
# 03305I90846    1
# Name: msisdn, Length: 186243, dtype: int64
#
# UPW    209593
# Name: pcircle, dtype: int64
#
# 2016-07-04    3150
# 2016-07-05    3127
# 2016-07-07    3116
# 2016-06-20    3099
# 2016-06-17    3082
#               ...
# 2016-06-04    1559
# 2016-08-18    1407
# 2016-08-19    1132
# 2016-08-20     788
# 2016-08-21     324
# Name: pdate, Length: 82, dtype: int64

# %%
# dropping some features

df.drop(['pdate','pcircle','msisdn'],axis='columns', inplace=True)
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
# correlations

df_corr = df.corr()
df1_corr = df_corr.index
plt.figure(figsize=(20,20))

# heat map

a=sns.heatmap(df[df1_corr].corr(),annot=True)

# %%
sns.countplot(x="label",data=df)
plt.show()

# %%
sns.barplot(y="payback30",x="label",data=df)
plt.show()
sns.barplot(y="payback90",x="label",data=df)
plt.show()

# %%
sns.countplot(y="maxamnt_loans90",data=df)
plt.show()
sns.barplot(y="maxamnt_loans30",x="label",data=df)
plt.show()
sns.barplot(y="maxamnt_loans90",x="label",data=df)
plt.show()

# %%
sns.barplot(y="daily_decr30",x="label",data=df)
plt.show()
sns.barplot(y="daily_decr90",x="label",data=df)
plt.show()

# %%
sns.barplot(y="rental30",x="label",data=df)
plt.show()
sns.barplot(y="rental90",x="label",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'],
#       dtype='object')

# %%
df2 = df.copy() 
df2_x = df2.drop('label', axis = 1)
y1 = df2['label']
print(df2_x.shape)
print(y1.shape)
# Out:
# (209593, 32)
# (209593,)

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(df2_x,y1)
print(model.feature_importances_)

feat_importances = pd.Series(model.feature_importances_, index=df2_x.columns)
feat_importances.nlargest(32).plot(kind='barh')
plt.show()
# Out:
# [0.07572416 0.12570401 0.11751907 0.07601423 0.07328787 0.0498043
#  0.00381512 0.02651097 0.03072488 0.01626965 0.03821698 0.02273768
#  0.0379951  0.03216214 0.03733479 0.03158968 0.03102436 0.04462425
#  0.00279897 0.00195811 0.00330229 0.00099806 0.01837023 0.02355732
#  0.00210964 0.00392719 0.0072292  0.02204041 0.00783223 0.00349894
#  0.01422075 0.01709742]

# %%
# Checking Outliers

out=['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
       'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
       'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
       'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
       'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
       'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
       'maxamnt_loans30', 'cnt_loans90', 'amnt_loans90',
         'payback30', 'payback90']
q3 = df[out].quantile(0.75)
q1 = df[out].quantile(0.25)
iqr = q3 - q1
print('IQR')
print(iqr)
# Out:
# IQR
# aon                       736.000
# daily_decr30             7201.560
# daily_decr90             7760.098
# rental30                 3076.520
# rental90                 3901.530
# last_rech_date_ma           6.000
# last_rech_date_da           0.000
# last_rech_amt_ma         1539.000
# cnt_ma_rech30               4.000
# fr_ma_rech30                6.000
# sumamnt_ma_rech30        8470.000
# medianamnt_ma_rech30     1154.000
# medianmarechprebal30       72.000
# cnt_ma_rech90               6.000
# fr_ma_rech90                8.000
# sumamnt_ma_rech90       13683.000
# medianamnt_ma_rech90     1151.000
# medianmarechprebal90       64.710
# cnt_da_rech30               0.000
# fr_da_rech30                0.000
# cnt_da_rech90               0.000
# fr_da_rech90                0.000
# cnt_loans30                 3.000
# amnt_loans30               18.000
# maxamnt_loans30             0.000
# cnt_loans90                 4.000
# amnt_loans90               24.000
# ...

# %%
out2=sns.boxplot(data=df[['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
       'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
       'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
       'medianamnt_ma_rech30', ]])
out2.set_xticklabels(out2.get_xticklabels(), rotation=90)
fig=plt.gcf()
fig.set_size_inches(8,8)

# %%
out3=sns.boxplot(data=df[['medianmarechprebal30', 'cnt_ma_rech90',
       'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
       'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
       'maxamnt_loans30', 'cnt_loans90', 'amnt_loans90',
         'payback30', 'payback90']])
out2.set_xticklabels(out2.get_xticklabels(), rotation=90)
fig=plt.gcf()
fig.set_size_inches(8,8)

# %%
df.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# dtype: int64

# %%
out4=sns.boxplot(data=df[['aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
       'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
       'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
       'medianamnt_ma_rech30', ]])
chart.set_xticklabels(out4.get_xticklabels(), rotation=90)
fig=plt.gcf()
fig.set_size_inches(8,8)

# %%
chart=sns.boxplot(data=df[['medianmarechprebal30', 'cnt_ma_rech90',
       'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
       'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
       'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
       'maxamnt_loans30', 'cnt_loans90', 'amnt_loans90',
         'payback30', 'payback90']])
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
fig=plt.gcf()
fig.set_size_inches(8,8)

# %%
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
# dropping columns

df.drop(['last_rech_date_da','cnt_da_rech30','fr_da_rech30','cnt_da_rech90','fr_da_rech90','maxamnt_loans30' ],axis='columns', inplace=True)
df
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# ...

# %%
df_final = df

# %%
df_final
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# ...

# %%
df_final.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_amt_ma  \
# count  209593.000000  209593.000000      209593.000000     209593.000000
# mean     2692.581910    3483.406534        3755.847800       2064.452797
# std      4308.586781    5770.461279       53905.892230       2370.786034
# min    -23737.140000  -24720.580000         -29.000000          0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaled_df_final=scaler.fit_transform(df_final)
X=scaled_df_final

# %%
X
# Out:
# array([[-2.64789583, -0.10357685, -0.25229941, ..., -0.22959366,
#          2.9046997 ,  2.39409346],
#        [ 0.37765836, -0.09776412,  0.73103667, ..., -0.22959366,
#         -0.38562959, -0.41923266],
#        [ 0.37765836, -0.10010243, -0.43201111, ..., -0.22959366,
#         -0.38562959, -0.41923266],
#        ...,
#        [ 0.37765836, -0.09378769,  0.70079045, ..., -0.22959366,
#          0.06820893, -0.04735622],
#        [ 0.37765836, -0.08428915,  0.77075515, ..., -0.22959366,
#         -0.38562959,  0.59938541],
#        [ 0.37765836, -0.08628398, -0.09674426, ..., -0.22959366,
#         -0.38562959, -0.41923266]])

# %%
df_final=df.drop(columns=["label"])
Y=df[["label"]]

# %%
Y
# Out:
#         label
# 0           0
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 209588      1
# 209589      1
# 209590      1
# 209591      1
# 209592      1
#
# [209593 rows x 1 columns]

# %% [markdown]
# # Training and Testing Models

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state = 0)

# %%
X_train.shape
# Out:
# (146715, 27)

# %%
def fit_ml_algo(algo, X_train, Y_train, X_test, cv):
    # One Pass
    model = algo.fit(X_train, Y_train)
    test_pred = model.predict(X_test)
    if (isinstance(algo, (LogisticRegression, 
                          KNeighborsClassifier, 
                          GaussianNB, 
                          DecisionTreeClassifier, 
                          RandomForestClassifier,
                          GradientBoostingClassifier))):
        probs = model.predict_proba(X_test)[:,1]
    else:
        probs = "Not Available"
    acc = round(model.score(X_test, Y_test) * 100, 2) 
    # CV 
    train_pred = model_selection.cross_val_predict(algo, 
                                                  X_train, 
                                                  Y_train, 
                                                  cv=cv, 
                                                  n_jobs = -1)
    acc_cv = round(metrics.accuracy_score(Y_train, train_pred) * 100, 2)
    return train_pred, test_pred, acc, acc_cv, probs

# %% [markdown]
# # Building Machine Learning Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
import time
# Utility function to report best scores
def report(results, n_top=5):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            
# Specify parameters and distributions to sample from
param_dist = {'penalty': ['l2', 'l1'], 
                         'class_weight': [None, 'balanced'],
                         'C': np.logspace(-20, 20, 10000), 
                         'intercept_scaling': np.logspace(-20, 20, 10000)}

# Run Randomized Search
n_iter_search = 10
lrc = LogisticRegression()
random_search = RandomizedSearchCV(lrc, 
                                   n_jobs=-1, 
                                   param_distributions=param_dist, 
                                   n_iter=n_iter_search)

start = time.time()
random_search.fit(X_train, Y_train)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time.time() - start), n_iter_search))
report(random_search.cv_results_)
# Out:
# RandomizedSearchCV took 15.82 seconds for 10 candidates parameter settings.
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 2.0933029390609274e-12, 'class_weight': None, 'C': 5588235854649.062}
#
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 236.72134718820152, 'class_weight': 'balanced', 'C': 21.783808644775124}
#
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 4.066875955298795e-08, 'class_weight': 'balanced', 'C': 61203840.948050395}
#
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# Parameters: {'penalty': 'l2', 'intercept_scaling': 59576845976.12788, 'class_weight': 'balanced', 'C': 1848956495.497065}
#
# Model with rank: 1
# Mean validation score: 1.000 (std: 0.000)
# ...

# %%
from sklearn import datasets, model_selection, tree, preprocessing, metrics, linear_model
from sklearn.metrics import precision_recall_fscore_support, roc_curve, auc
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LinearRegression, Ridge, Lasso, SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
import datetime
from sklearn.neighbors import KNeighborsClassifier
start_time = time.time()
train_pred_log, test_pred_log, acc_log, acc_cv_log, probs_log = fit_ml_algo(LogisticRegression(n_jobs = -1),X_train,Y_train,X_test,10)
log_time = (time.time() - start_time)
print("Accuracy: %s" % acc_log)
print("Accuracy CV 10-Fold: %s" % acc_cv_log)
print("Running Time: %s" % datetime.timedelta(seconds=log_time))
# Out:
# Accuracy: 100.0
# Accuracy CV 10-Fold: 100.0
# Running Time: 0:00:16.521187
